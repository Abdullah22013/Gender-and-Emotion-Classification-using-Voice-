# %%
import pandas as pd
import numpy as np
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r'C:\ACADEMIC\SEM 5\ML\course project work\ML_FinalSubmission_\Gender-and-Emotion-Classification-using-Voice-\assets\scaled_voice_data.csv')
x = df.drop('gender', axis=1)
y = df['gender']
le = LabelEncoder()
Y_encoded = le.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(x, Y_encoded, test_size = 0.2, random_state = 100)

df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      kurt  \
# 0  0.602758  0.355976  1.055699 -0.142117  1.567427  1.027768 -0.210519
# 1  0.642158  0.219537  0.936464  1.053742  0.626879 -0.852602 -0.204561
# 2 -0.495719 -0.169618 -0.309233  0.445927 -1.448345 -1.307654 -0.139015
# 3 -0.708439  0.021716 -0.541947  0.177739 -1.431259 -0.993061 -0.154961
# 4  1.763427 -1.871090  1.387941  1.710837  0.914199 -1.441506 -0.130894
#
#      sp.ent       sfm      mode   meanfun    minfun   modindx  gender
# 0 -0.540272 -0.835728  1.318746 -0.357016  0.582726 -1.266497    male
# 1  0.214854  0.510834  0.914485  0.223601 -1.088261  0.743066  female
# 2 -0.257852  0.191444  0.056141  0.986513 -1.022684  0.238451  female
# 3  0.057054  0.131876 -2.141210  0.675466 -0.643929  2.324912  female
# 4 -2.543075 -1.691409  0.917164  1.851877  0.805841 -0.133960  female

# %% [markdown]
# ### Decision Tree with criterion set to "Gini"

# %%
Tree_depth = [4,8,10,15,20]

for i in Tree_depth:
    DT = DecisionTreeClassifier(criterion = "gini", max_depth = i)
    DT.fit(X_train, y_train)
    y_pred =DT.predict(X_test)
    
    print("Accuracy with tree depth {} is:".format(i), accuracy_score(y_test, y_pred))
    print("Recall with tree depth {} is:".format(i), recall_score(y_test, y_pred))
    print("F1 Score with tree depth {} is:".format(i), f1_score(y_test, y_pred))
    print("Precision with tree depth {} is:".format(i), precision_score(y_test, y_pred))
    print("\n")
# Out:
# Accuracy with tree depth 4 is: 0.9716088328075709
# Recall with tree depth 4 is: 0.963076923076923
# F1 Score with tree depth 4 is: 0.9720496894409938
# Precision with tree depth 4 is: 0.9811912225705329
#
#
# Accuracy with tree depth 8 is: 0.9684542586750788
# Recall with tree depth 8 is: 0.9661538461538461
# F1 Score with tree depth 8 is: 0.9691358024691358
# Precision with tree depth 8 is: 0.9721362229102167
#
#
# Accuracy with tree depth 10 is: 0.9621451104100947
# Recall with tree depth 10 is: 0.96
# F1 Score with tree depth 10 is: 0.9629629629629629
# Precision with tree depth 10 is: 0.9659442724458205
#
#
# Accuracy with tree depth 15 is: 0.9637223974763407
# Recall with tree depth 15 is: 0.96
# F1 Score with tree depth 15 is: 0.964451313755796
# Precision with tree depth 15 is: 0.968944099378882
#
#
# Accuracy with tree depth 20 is: 0.9637223974763407
# Recall with tree depth 20 is: 0.963076923076923
# F1 Score with tree depth 20 is: 0.9645608628659477
# Precision with tree depth 20 is: 0.9660493827160493

# %% [markdown]
# ### Decision Tree with Criterion= "Entropy"

# %%
from sklearn import tree
import matplotlib.pyplot as plt

for i in Tree_depth:

    DT = DecisionTreeClassifier(criterion = "entropy", max_depth = i)

    DT.fit(X_train, y_train)

    y_pred =DT.predict(X_test)
    
    # Model Accuracy

    print("Accuracy with tree depth {} is:".format(i), accuracy_score(y_test, y_pred))
    print("Recall with tree depth {} is:".format(i), recall_score(y_test, y_pred))
    print("F1 Score with tree depth {} is:".format(i), f1_score(y_test, y_pred))
    print("Precision with tree depth {} is:".format(i), precision_score(y_test, y_pred))
    print("\n")
# Out:
# Accuracy with tree depth 4 is: 0.9668769716088328
# Recall with tree depth 4 is: 0.963076923076923
# F1 Score with tree depth 4 is: 0.9675425038639877
# Precision with tree depth 4 is: 0.9720496894409938
#
#
# Accuracy with tree depth 8 is: 0.9684542586750788
# Recall with tree depth 8 is: 0.96
# F1 Score with tree depth 8 is: 0.968944099378882
# Precision with tree depth 8 is: 0.9780564263322884
#
#
# Accuracy with tree depth 10 is: 0.9684542586750788
# Recall with tree depth 10 is: 0.963076923076923
# F1 Score with tree depth 10 is: 0.9690402476780186
# Precision with tree depth 10 is: 0.9750778816199377
#
#
# Accuracy with tree depth 15 is: 0.9700315457413249
# Recall with tree depth 15 is: 0.96
# F1 Score with tree depth 15 is: 0.9704510108864697
# Precision with tree depth 15 is: 0.9811320754716981
#
#
# Accuracy with tree depth 20 is: 0.9700315457413249
# Recall with tree depth 20 is: 0.963076923076923
# F1 Score with tree depth 20 is: 0.9705426356589147
# Precision with tree depth 20 is: 0.978125

# %% [markdown]
# ### Building the Tree

# %%
fig, axes = plt.subplots(nrows=1,ncols = 1,figsize = (10,10), dpi=900)

finalDT = DecisionTreeClassifier(criterion = "entropy", max_depth = 4)

finalDT.fit(X_train, y_train)

tree.plot_tree(finalDT)

fig.savefig('C:\ACADEMIC\SEM 5\ML\course project work\ML_FinalSubmission_\Gender-and-Emotion-Classification-using-Voice-\images/Decision_Tree.png', dpi=250)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\A'
# <>:9: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Abdullah shujat\AppData\Local\Temp\ipykernel_10496\3375995761.py:9: SyntaxWarning: invalid escape sequence '\A'
#   fig.savefig('C:\ACADEMIC\SEM 5\ML\course project work\ML_FinalSubmission_\Gender-and-Emotion-Classification-using-Voice-\images/Decision_Tree.png', dpi=250)
